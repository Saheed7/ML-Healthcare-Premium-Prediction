# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

# %%
df = pd.read_csv("premiums.csv")
df.head(3)
# Out:
#    Age  Gender     Region Marital_status Physical_Activity Stress_Level  \
# 0   56  Female  Southeast      Unmarried            Medium       Medium
# 1   38  Female  Northeast        Married               Low         High
# 2   18  Female  Southwest      Unmarried            Medium         High
#
#    Number Of Dependants BMI_Category Smoking_Status Employment_Status  \
# 0                     2       Normal     No Smoking     Self-Employed
# 1                     5   Overweight     Occasional        Freelancer
# 2                     0       Normal     No Smoking        Freelancer
#
#   Income_Level  Income_Lakhs      Medical History Insurance_Plan  \
# 0    25L - 40L            37  High blood pressure           Gold
# 1    10L - 25L            10           No Disease         Silver
# 2         <10L             9           No Disease         Bronze
#
#    Annual_Premium_Amount
# 0                  27944
# 1                  21108
# 2                   8459

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Region', 'Marital_status', 'Physical_Activity',
#        'Stress_Level', 'Number Of Dependants', 'BMI_Category',
#        'Smoking_Status', 'Employment_Status', 'Income_Level', 'Income_Lakhs',
#        'Medical History', 'Insurance_Plan', 'Annual_Premium_Amount'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.head(1)
# Out:
#    age  gender     region marital_status physical_activity stress_level  \
# 0   56  Female  Southeast      Unmarried            Medium       Medium
#
#    number_of_dependants bmi_category smoking_status employment_status  \
# 0                     2       Normal     No Smoking     Self-Employed
#
#   income_level  income_lakhs      medical_history insurance_plan  \
# 0    25L - 40L            37  High blood pressure           Gold
#
#    annual_premium_amount
# 0                  27944

# %% [markdown]
# ### Handle Missing Values (na)

# %%
df.isna().sum()
# Out:
# age                       0
# gender                    0
# region                    0
# marital_status            0
# physical_activity         0
# stress_level              0
# number_of_dependants      0
# bmi_category              0
# smoking_status            9
# employment_status         7
# income_level             18
# income_lakhs              0
# medical_history           0
# insurance_plan            0
# annual_premium_amount     0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# physical_activity        0
# stress_level             0
# number_of_dependants     0
# bmi_category             0
# smoking_status           0
# employment_status        0
# income_level             0
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# dtype: int64

# %% [markdown]
# ### Handle Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                age  number_of_dependants  income_lakhs  annual_premium_amount
# count  9973.000000           9973.000000   9973.000000            9973.000000
# mean     41.319362              3.195628     23.382232           19503.816705
# std      58.044687             21.679565     32.334811            8898.079736
# min      18.000000              0.000000      1.000000            3582.000000
# 25%      24.000000              0.000000      6.000000           11774.000000
# 50%      37.000000              2.000000     16.000000           19314.000000
# 75%      50.000000              3.000000     31.000000           26500.000000
# max    1178.000000            456.000000    960.000000           45854.000000

# %% [markdown]
# ### Numeric Columns
# ### Univariate Analysis

# %% [markdown]
# ### Box Plots for Numeric Columns

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'annual_premium_amount'], dtype='object')

# %%
for col in numeric_columns:
    sns.boxplot(x=df[col])
    plt.show()

# %%
df[df.age> 100]
# Out:
#        age  gender     region marital_status physical_activity stress_level  \
# 79     128  Female  Northwest        Married               Low         High
# 129    128    Male  Southeast        Married               Low         High
# 170   1178    Male  Southwest      Unmarried            Medium       Medium
# 533    567    Male  Southeast        Married            Medium       Medium
# 652    456  Female  Southeast      Unmarried            Medium          Low
# 767   1178  Female  Southeast      Unmarried            Medium         High
# 826    456  Female  Southwest      Unmarried               Low       Medium
# 1426  1178  Female  Northwest      Unmarried            Medium       Medium
# 1554  1178    Male  Southwest      Unmarried              High          Low
# 1997   128    Male  Southwest      Unmarried               Low       Medium
# 2095   567  Female  Southwest        Married              High         High
# 2172  1178  Female  Southwest        Married            Medium         High
# 2255   128    Male  Southwest      Unmarried            Medium       Medium
# 2312   456  Female  Southeast        Married            Medium       Medium
# 2317   456  Female  Southeast        Married               Low          Low
# 2551  1178    Male  Southeast        Married            Medium       Medium
# 2682  1178  Female  Southwest        Married               Low         High
# 2934   567  Female  Northeast      Unmarried            Medium         High
# 3222   567  Female  Southeast      Unmarried              High         High
# 3776  1178    Male  Southwest        Married            Medium         High
# 4152   128  Female  Southeast      Unmarried            Medium          Low
# 4189   128  Female  Northwest        Married            Medium         High
# 4281  1178    Male  Northeast        Married            Medium         High
# 4350   456  Female  Southwest      Unmarried            Medium       Medium
# 4368   128  Female  Northeast        Married            Medium         High
# 4396  1178  Female  Southeast        Married            Medium         High
# 4480   567    Male  Southeast        Married            Medium         High
# 4693  1178    Male  Northeast      Unmarried              High         High
# 4916   567  Female  Northeast      Unmarried               Low         High
# 4980   567  Female  Northwest        Married            Medium         High
# 4994   456    Male  Southeast        Married            Medium          Low
# 5215   456  Female  Northeast      Unmarried            Medium       Medium
# 5342   567  Female  Southeast        Married              High       Medium
# 5711   456    Male  Northwest        Married              High          Low
# 5998   456  Female  Northwest      Unmarried            Medium       Medium
# 6324  1178  Female  Southwest      Unmarried            Medium         High
# 6413  1178    Male  Northeast        Married            Medium         High
# 6780   456  Female  Northeast      Unmarried               Low          Low
# 6803   128  Female  Southeast      Unmarried              High         High
# 6939  1178    Male  Southeast      Unmarried              High       Medium
# 7205   128  Female  Southeast      Unmarried            Medium          Low
# 7320  1178  Female  Southeast        Married            Medium       Medium
# 7346   128  Female  Northeast      Unmarried            Medium          Low
# 7490   128    Male  Southwest        Married            Medium          Low
# 7857  1178    Male  Southwest        Married              High          Low
# 7870  1178    Male  Southwest        Married              High       Medium
# 8209   128  Female  Southeast        Married               Low       Medium
# 8335  1178  Female  Southwest        Married            Medium          Low
# 8348   567    Male  Southwest        Married            Medium       Medium
# 8513   128  Female  Southwest      Unmarried              High         High
# 8589   567    Male  Northeast      Unmarried            Medium       Medium
# 9065   567  Female  Southeast        Married            Medium       Medium
# 9237  1178  Female  Northeast      Unmarried            Medium         High
# 9238   128    Male  Southeast      Unmarried            Medium       Medium
# 9433   567  Female  Northwest        Married            Medium         High
# 9587   567  Female  Southeast      Unmarried            Medium       Medium
# 9759   567  Female  Southwest        Married            Medium       Medium
# 9865  1178  Female  Southwest        Married            Medium       Medium
#
#       number_of_dependants bmi_category smoking_status employment_status  \
# 79                       3      Obesity     Occasional     Self-Employed
# 129                      3      Obesity        Regular     Self-Employed
# 170                      0       Normal        Regular          Salaried
# 533                      2       Normal        Regular     Self-Employed
# 652                      1       Normal     No Smoking          Salaried
# 767                      0      Obesity     No Smoking     Self-Employed
# 826                      2      Obesity     No Smoking     Self-Employed
# 1426                     0       Normal        Regular     Self-Employed
# 1554                     0       Normal     No Smoking        Freelancer
# 1997                     0      Obesity     No Smoking          Salaried
# 2095                     4   Overweight        Regular        Freelancer
# 2172                     2      Obesity     No Smoking          Salaried
# 2255                     0       Normal     No Smoking          Salaried
# 2312                     3      Obesity     Occasional          Salaried
# 2317                     3   Overweight     Occasional          Salaried
# 2551                     3       Normal     No Smoking     Self-Employed
# 2682                     2      Obesity     No Smoking          Salaried
# 2934                     0       Normal        Regular          Salaried
# 3222                     2       Normal     No Smoking          Salaried
# 3776                     5       Normal        Regular          Salaried
# 4152                     0       Normal     No Smoking        Freelancer
# 4189                     2   Overweight     No Smoking          Salaried
# 4281                     3   Overweight        Regular          Salaried
# 4350                     1       Normal     No Smoking          Salaried
# 4368                     5      Obesity     No Smoking          Salaried
# 4396                     3   Overweight     Occasional          Salaried
# 4480                     3       Normal        Regular          Salaried
# 4693                     0      Obesity     Occasional     Self-Employed
# 4916                     1   Overweight     No Smoking          Salaried
# 4980                     5       Normal     No Smoking          Salaried
# 4994                     3       Normal        Regular          Salaried
# 5215                     0       Normal     No Smoking          Salaried
# 5342                     4   Overweight     Occasional          Salaried
# 5711                     2      Obesity     No Smoking          Salaried
# 5998                     0       Normal     Occasional          Salaried
# 6324                     0  Underweight        Regular        Freelancer
# 6413                     3   Overweight     No Smoking        Freelancer
# 6780                     1   Overweight        Regular        Freelancer
# 6803                     1      Obesity     No Smoking          Salaried
# 6939                     2   Overweight        Regular        Freelancer
# 7205                     1      Obesity     No Smoking        Freelancer
# 7320                     3  Underweight     No Smoking        Freelancer
# 7346                     1   Overweight        Regular     Self-Employed
# 7490                     3       Normal     Occasional     Self-Employed
# 7857                     3       Normal        Regular        Freelancer
# 7870                     2   Overweight     No Smoking     Self-Employed
# 8209                     4  Underweight     No Smoking          Salaried
# 8335                     1  Underweight     No Smoking     Self-Employed
# 8348                     3       Normal        Regular        Freelancer
# 8513                     0   Overweight     No Smoking        Freelancer
# 8589                     1      Obesity        Regular          Salaried
# 9065                     2       Normal     No Smoking        Freelancer
# 9237                     1      Obesity     No Smoking     Self-Employed
# 9238                     0       Normal        Regular     Self-Employed
# 9433                     5   Overweight     Occasional          Salaried
# 9587                     0      Obesity     No Smoking        Freelancer
# 9759                     1       Normal     Occasional     Self-Employed
# 9865                     3       Normal     No Smoking        Freelancer
#
#      income_level  income_lakhs                      medical_history  \
# 79      25L - 40L            38                        Heart disease
# 129     10L - 25L            12                           No Disease
# 170          <10L             5                        Heart disease
# 533         > 40L            43                  High blood pressure
# 652         > 40L            52                   Diabetes & Thyroid
# 767     25L - 40L            39                        Heart disease
# 826          <10L             2       Diabetes & High blood pressure
# 1426    25L - 40L            31                           No Disease
# 1554    25L - 40L            39                             Diabetes
# 1997         <10L             5                              Thyroid
# 2095         <10L             4                             Diabetes
# 2172         <10L             2                             Diabetes
# 2255    10L - 25L            25                           No Disease
# 2312        > 40L            93                             Diabetes
# 2317         <10L             2                           No Disease
# 2551    10L - 25L            23                             Diabetes
# 2682    10L - 25L            22                             Diabetes
# 2934    10L - 25L            15                             Diabetes
# 3222         <10L             2                  High blood pressure
# 3776        > 40L            54                           No Disease
# 4152    25L - 40L            27                           No Disease
# 4189    10L - 25L            14                           No Disease
# 4281         <10L             7                             Diabetes
# 4350         <10L             6                           No Disease
# 4368    25L - 40L            25                  High blood pressure
# 4396         <10L             4                   Diabetes & Thyroid
# 4480    10L - 25L            21                           No Disease
# 4693        > 40L            64                           No Disease
# 4916         <10L             3                  High blood pressure
# 4980         <10L             5                   Diabetes & Thyroid
# 4994    10L - 25L            14                           No Disease
# 5215    10L - 25L            24                           No Disease
# 5342         <10L             5  High blood pressure & Heart disease
# 5711    25L - 40L            40                              Thyroid
# 5998         <10L             8                           No Disease
# 6324    10L - 25L            14                              Thyroid
# 6413    10L - 25L            22                             Diabetes
# 6780    10L - 25L            22                  High blood pressure
# 6803         <10L             4                  High blood pressure
# 6939         <10L             5                              Thyroid
# 7205         <10L             1                           No Disease
# 7320    10L - 25L            24                           No Disease
# 7346    25L - 40L            31                  High blood pressure
# 7490         <10L             9                             Diabetes
# 7857    25L - 40L            30                  High blood pressure
# 7870        > 40L            45                              Thyroid
# 8209         <10L             5                  High blood pressure
# 8335         <10L             6                              Thyroid
# 8348         <10L             1                           No Disease
# 8513         <10L             9                             Diabetes
# 8589         <10L             2                             Diabetes
# 9065    10L - 25L            10                           No Disease
# 9237    25L - 40L            26                           No Disease
# 9238    25L - 40L            40                             Diabetes
# 9433    10L - 25L            21                  High blood pressure
# 9587    25L - 40L            26                              Thyroid
# 9759    25L - 40L            35                        Heart disease
# 9865         <10L             9                   Diabetes & Thyroid
#
#      insurance_plan  annual_premium_amount
# 79           Silver                  30696
# 129            Gold                  37061
# 170          Silver                  18349
# 533            Gold                  31545
# 652            Gold                  15927
# 767            Gold                  37181
# 826          Silver                  28086
# 1426         Silver                  13094
# 1554         Silver                   9423
# 1997         Bronze                  17713
# 2095         Bronze                  17081
# 2172         Silver                  25392
# 2255         Bronze                   5705
# 2312           Gold                  28605
# 2317         Silver                  21515
# 2551           Gold                  28356
# 2682           Gold                  30624
# 2934           Gold                  28091
# 3222         Bronze                  11848
# 3776           Gold                  25746
# 4152         Bronze                   5827
# 4189         Silver                  19680
# 4281         Silver                  27405
# 4350         Silver                   9943
# 4368         Silver                  26694
# 4396         Silver                  26443
# 4480         Bronze                  10301
# 4693         Silver                  15513
# 4916         Silver                  25646
# 4980         Bronze                  15079
# 4994         Silver                  18057
# 5215         Bronze                   4994
# 5342         Bronze                  18273
# 5711         Silver                  20908
# 5998         Bronze                  10585
# 6324           Gold                  20886
# 6413           Gold                  32583
# 6780           Gold                  30502
# 6803         Silver                  26449
# 6939         Bronze                  15861
# 7205         Silver                  12819
# 7320         Bronze                   7309
# 7346         Bronze                  11953
# 7490           Gold                  28720
# 7857         Silver                  18629
# 7870           Gold                  30587
# 8209         Bronze                  12969
# 8335         Silver                  24578
# 8348         Bronze                   9757
# 8513         Bronze                  10657
# 8589         Bronze                  17057
# 9065           Gold                  21940
# 9237         Bronze                  12046
# 9238           Gold                  31360
# 9433         Silver                  22455
# 9587         Silver                  23718
# 9759           Gold                  39703
# 9865         Silver                  21703

# %% [markdown]
# This age value is outrageous, and I concluded this is simply outliers! I used principle of statistics, common sense and domain knowledge

# %%
df[df.age> 100]['age'].unique()
# Out:
# array([ 128, 1178,  567,  456], dtype=int64)

# %% [markdown]
# Outlier Treatment: Age Column

# %%
df1 = df[df.age<= 100]
df1.age.describe()
# Out:
# count    9915.000000
# mean       37.743621
# std        13.975462
# min        18.000000
# 25%        24.000000
# 50%        37.000000
# 75%        50.000000
# max        72.000000
# Name: age, dtype: float64

# %% [markdown]
# Outlier Treatment: Income Column

# %%
df.income_lakhs.quantile([0.25,0.75])
# Out:
# 0.25     6.0
# 0.75    31.0
# Name: income_lakhs, dtype: float64

# %%
def get_iqr_bounds(col):
    Q1, Q3 = col.quantile([0.25, 0.75])
    IQR = Q3-Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

lower, upper = get_iqr_bounds(df1['income_lakhs'])
lower, upper
# Out:
# (-31.5, 68.5)

# %%
df1[df1.income_lakhs>upper].shape
# Out:
# (697, 15)

# %% [markdown]
# There are many legitimate records that we will get rid of if we use IQR bounds method. Hence after discussion with business we decided to use a simple quantile bound

# %%
quantile_thresold = df1.income_lakhs.quantile(0.999)
quantile_thresold
# Out:
# 136.12000000048283

# %%
df1[df1.income_lakhs>quantile_thresold].shape
# Out:
# (10, 15)

# %%
df2 = df1[df1.income_lakhs<= quantile_thresold].copy()
df2.shape
# Out:
# (9905, 15)

# %% [markdown]
# ### Outlier Treatment: Dependants

# %%
df2['number_of_dependants'].describe()
# Out:
# count    9905.000000
# mean        3.205553
# std        21.753158
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         3.000000
# max       456.000000
# Name: number_of_dependants, dtype: float64

# %%
sns.histplot(df2['number_of_dependants'],bins=20)
# Out:
# <Axes: xlabel='number_of_dependants', ylabel='Count'>

# %%
dependant_thresold = df2['number_of_dependants'].quantile(0.99)
dependant_thresold
# Out:
# 5.0

# %%
df3 = df2[df2['number_of_dependants']<=dependant_thresold].copy()
df3['number_of_dependants'].describe()
# Out:
# count    9858.000000
# mean        1.919963
# std         1.503027
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: number_of_dependants, dtype: float64

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))  # Adjust the size as necessary

for i, column in enumerate(numeric_columns):
    ax = axs[i//2, i%2]  # Determines the position of the subplot in the grid
    sns.histplot(df3[column], kde=True, ax=ax)
    ax.set_title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Analysis: Numeric Columns

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))  # Adjust the size as necessary

for i, column in enumerate(numeric_columns):
    ax = axs[i//2, i%2]  # Determines the position of the subplot in the grid
    sns.histplot(df3[column], kde=True, ax=ax)
    ax.set_title(column)

plt.tight_layout()
plt.show()

# %%
numeric_features = ['age', 'income_lakhs', 'number_of_dependants']

fig, axes = plt.subplots(1, len(numeric_features), figsize=(18, 6))  # Adjust figure size as necessary

for ax, column in zip(axes, numeric_features):
    sns.scatterplot(x=df3[column], y=df3['annual_premium_amount'], ax=ax)
    ax.set_title(f'{column} vs. annual_premium_amount')
    ax.set_xlabel(column)
    ax.set_ylabel('annual_premium_amount')

plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# ## 2. Categorical Columns

# %%
df3.head(2)
# Out:
#    age  gender     region marital_status physical_activity stress_level  \
# 0   56  Female  Southeast      Unmarried            Medium       Medium
# 1   38  Female  Northeast        Married               Low         High
#
#    number_of_dependants bmi_category smoking_status employment_status  \
# 0                     2       Normal     No Smoking     Self-Employed
# 1                     5   Overweight     Occasional        Freelancer
#
#   income_level  income_lakhs      medical_history insurance_plan  \
# 0    25L - 40L            37  High blood pressure           Gold
# 1    10L - 25L            10           No Disease         Silver
#
#    annual_premium_amount
# 0                  27944
# 1                  21108

# %%
categorical_cols = ['gender', 'region', 'marital_status', 'physical_activity', 'stress_level', 'bmi_category', 'smoking_status', 'employment_status', 'income_level', 'medical_history', 'insurance_plan']
for col in categorical_cols:
    print(col, ":", df3[col].unique())
# Out:
# gender : ['Female' 'Male']
# region : ['Southeast' 'Northeast' 'Southwest' 'Northwest']
# marital_status : ['Unmarried' 'Married']
# physical_activity : ['Medium' 'Low' 'High']
# stress_level : ['Medium' 'High' 'Low']
# bmi_category : ['Normal' 'Overweight' 'Obesity' 'Underweight']
# smoking_status : ['No Smoking' 'Occasional' 'Regular']
# employment_status : ['Self-Employed' 'Freelancer' 'Salaried']
# income_level : ['25L - 40L' '10L - 25L' '<10L' '> 40L']
# medical_history : ['High blood pressure' 'No Disease' 'Thyroid'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid' 'Diabetes'
#  'Heart disease' 'Diabetes & High blood pressure'
#  'Diabetes & Heart disease']
# insurance_plan : ['Gold' 'Silver' 'Bronze']

# %% [markdown]
# ### Univariate Analysis

# %%
df3.head(2)
# Out:
#    age  gender     region marital_status physical_activity stress_level  \
# 0   56  Female  Southeast      Unmarried            Medium       Medium
# 1   38  Female  Northeast        Married               Low         High
#
#    number_of_dependants bmi_category smoking_status employment_status  \
# 0                     2       Normal     No Smoking     Self-Employed
# 1                     5   Overweight     Occasional        Freelancer
#
#   income_level  income_lakhs      medical_history insurance_plan  \
# 0    25L - 40L            37  High blood pressure           Gold
# 1    10L - 25L            10           No Disease         Silver
#
#    annual_premium_amount
# 0                  27944
# 1                  21108

# %%
pct_count = df3['gender'].value_counts(normalize=True)*100
pct_count
# Out:
# gender
# Female    59.870156
# Male      40.129844
# Name: proportion, dtype: float64

# %%
sns.barplot(x=pct_count.index, y=pct_count.values)
# Out:
# <Axes: xlabel='gender'>

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 18))  # Adjust figure size as necessary
axes = axes.flatten()  # Flatten the 2D array of axes into 1D for easier iteration

for ax, column in zip(axes, categorical_cols):
    # Calculate the percentage distribution of each category
    category_counts = df3[column].value_counts(normalize=True) * 100  # normalize=True gives the relative frequencies
    
    # Plotting the distribution using barplot
    sns.barplot(x=category_counts.index, y=category_counts.values, ax=ax)
    ax.set_title(f'Percentage Distribution of {column}')
    ax.set_ylabel('Percentage of Policyholders (%)')
    ax.set_xlabel(column)  # Set xlabel to the column name for clarity

plt.tight_layout()  # Adjusts plot parameters for better fit in the figure window
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
# Cross-tabulation of gender and smoking status
crosstab = pd.crosstab(df3['income_level'], df3['insurance_plan'])
print(crosstab)

# Plotting the crosstab
crosstab.plot(kind='bar', stacked=True)
plt.title('Income vs Plan')
plt.ylabel('Count')
plt.show()
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L          822   909     998
# 25L - 40L          533   733     733
# <10L              2266   184    1366
# > 40L               55   788     471

# %%
sns.heatmap(crosstab, annot=True, cmap='coolwarm',fmt="d")
plt.title('Heatmap of Income vs Plan')
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
df3.head(2)
# Out:
#    age  gender     region marital_status physical_activity stress_level  \
# 0   56  Female  Southeast      Unmarried            Medium       Medium
# 1   38  Female  Northeast        Married               Low         High
#
#    number_of_dependants bmi_category smoking_status employment_status  \
# 0                     2       Normal     No Smoking     Self-Employed
# 1                     5   Overweight     Occasional        Freelancer
#
#   income_level  income_lakhs      medical_history insurance_plan  \
# 0    25L - 40L            37  High blood pressure           Gold
# 1    10L - 25L            10           No Disease         Silver
#
#    annual_premium_amount
# 0                  27944
# 1                  21108

# %% [markdown]
# ### Calculate Risk Score

# %%
# Define the risk scores for each condition
risk_scores = {
    "diabetes": 6,
    "heart disease": 8,
    "high blood pressure":6,
    "thyroid": 5,
    "no disease": 0,
    "none":0
}

df3[['disease1', 'disease2']] = df3['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
df3['disease1'] = df3['disease1'].fillna('none')
df3['disease2'] = df3['disease2'].fillna('none')
df3['total_risk_score'] = 0

for disease in ['disease1', 'disease2']:
    df3['total_risk_score'] += df3[disease].map(risk_scores)

# Normalize the risk score to a range of 0 to 1
max_score = df3['total_risk_score'].max()
min_score = df3['total_risk_score'].min()
df3['normalized_risk_score'] = (df3['total_risk_score'] - min_score) / (max_score - min_score)
df3.head(2)
# Out:
#    age  gender     region marital_status physical_activity stress_level  \
# 0   56  Female  Southeast      Unmarried            Medium       Medium
# 1   38  Female  Northeast        Married               Low         High
#
#    number_of_dependants bmi_category smoking_status employment_status  \
# 0                     2       Normal     No Smoking     Self-Employed
# 1                     5   Overweight     Occasional        Freelancer
#
#   income_level  income_lakhs      medical_history insurance_plan  \
# 0    25L - 40L            37  High blood pressure           Gold
# 1    10L - 25L            10           No Disease         Silver
#
#    annual_premium_amount             disease1 disease2  total_risk_score  \
# 0                  27944  high blood pressure     none                 6
# 1                  21108           no disease     none                 0
#
#    normalized_risk_score
# 0               0.428571
# 1               0.000000

# %% [markdown]
# ### Calculate Life Style Risk Score

# %%
def calculate_life_style_risk(row):
    physical_activity_risk_score = {
        "High": 0,
        "Medium": 1,
        "Low": 4
    }
    stress_risk_score = {
        "High": 4,
        "Medium": 1,
        "Low": 0
    }
    life_style_risk = physical_activity_risk_score[row['physical_activity']] + stress_risk_score[row['stress_level']]
    return life_style_risk

df3['lifestyle_risk_score'] = df3.apply(calculate_life_style_risk, axis=1)

# %%
sns.histplot(df3.lifestyle_risk_score, bins=20)
# Out:
# <Axes: xlabel='lifestyle_risk_score', ylabel='Count'>

# %% [markdown]
# ### Encode Text Columns

# %%
df3.head()
# Out:
#    age  gender     region marital_status physical_activity stress_level  \
# 0   56  Female  Southeast      Unmarried            Medium       Medium
# 1   38  Female  Northeast        Married               Low         High
# 2   18  Female  Southwest      Unmarried            Medium         High
# 3   55    Male  Northeast        Married              High       Medium
# 4   22    Male  Southeast      Unmarried            Medium         High
#
#    number_of_dependants bmi_category smoking_status employment_status  \
# 0                     2       Normal     No Smoking     Self-Employed
# 1                     5   Overweight     Occasional        Freelancer
# 2                     0       Normal     No Smoking        Freelancer
# 3                     3   Overweight     Occasional          Salaried
# 4                     2       Normal        Regular     Self-Employed
#
#   income_level  income_lakhs                      medical_history  \
# 0    25L - 40L            37                  High blood pressure
# 1    10L - 25L            10                           No Disease
# 2         <10L             9                           No Disease
# 3         <10L             9                              Thyroid
# 4    10L - 25L            13  High blood pressure & Heart disease
#
#   insurance_plan  annual_premium_amount             disease1       disease2  \
# 0           Gold                  27944  high blood pressure           none
# 1         Silver                  21108           no disease           none
# 2         Bronze                   8459           no disease           none
# 3         Silver                  21685              thyroid           none
# 4         Bronze                  15984  high blood pressure  heart disease
#
#    total_risk_score  normalized_risk_score  lifestyle_risk_score
# 0                 6               0.428571                     2
# 1                 0               0.000000                     8
# 2                 0               0.000000                     5
# 3                 5               0.357143                     1
# 4                14               1.000000                     5

# %%
df3['insurance_plan'] = df3['insurance_plan'].map({'Bronze': 1, 'Silver': 2, 'Gold': 3})

# %%
df3.head(2)
# Out:
#    age  gender     region marital_status physical_activity stress_level  \
# 0   56  Female  Southeast      Unmarried            Medium       Medium
# 1   38  Female  Northeast        Married               Low         High
#
#    number_of_dependants bmi_category smoking_status employment_status  \
# 0                     2       Normal     No Smoking     Self-Employed
# 1                     5   Overweight     Occasional        Freelancer
#
#   income_level  income_lakhs      medical_history  insurance_plan  \
# 0    25L - 40L            37  High blood pressure               3
# 1    10L - 25L            10           No Disease               2
#
#    annual_premium_amount             disease1 disease2  total_risk_score  \
# 0                  27944  high blood pressure     none                 6
# 1                  21108           no disease     none                 0
#
#    normalized_risk_score  lifestyle_risk_score
# 0               0.428571                     2
# 1               0.000000                     8

# %%
df3.income_level	.unique()
# Out:
# array(['25L - 40L', '10L - 25L', '<10L', '> 40L'], dtype=object)

# %%
df3['income_level'] = df3['income_level'].map({'<10L':1, '10L - 25L': 2, '25L - 40L':3, '> 40L':4})

# %%
nominal_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status']
df4 = pd.get_dummies(df3, columns=nominal_cols, drop_first=True, dtype=int)
df4.head(3)
# Out:
#    age physical_activity stress_level  number_of_dependants  income_level  \
# 0   56            Medium       Medium                     2             3
# 1   38               Low         High                     5             2
# 2   18            Medium         High                     0             1
#
#    income_lakhs      medical_history  insurance_plan  annual_premium_amount  \
# 0            37  High blood pressure               3                  27944
# 1            10           No Disease               2                  21108
# 2             9           No Disease               1                   8459
#
#               disease1  ... region_Southeast  region_Southwest  \
# 0  high blood pressure  ...                1                 0
# 1           no disease  ...                0                 0
# 2           no disease  ...                0                 1
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 0                         1                     0                        0
# 1                         0                     0                        1
# 2                         1                     0                        0
#
#    bmi_category_Underweight  smoking_status_Occasional  \
# 0                         0                          0
# 1                         0                          1
# 2                         0                          0
#
#    smoking_status_Regular  employment_status_Salaried  \
# 0                       0                           0
# 1                       0                           0
# 2                       0                           0
#
#    employment_status_Self-Employed
# 0                                1
# 1                                0
# 2                                0
#
# [3 rows x 26 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9858 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              9858 non-null   int64
#  1   physical_activity                9858 non-null   object
#  2   stress_level                     9858 non-null   object
#  3   number_of_dependants             9858 non-null   int64
#  4   income_level                     9858 non-null   int64
#  5   income_lakhs                     9858 non-null   int64
#  6   medical_history                  9858 non-null   object
#  7   insurance_plan                   9858 non-null   int64
#  8   annual_premium_amount            9858 non-null   int64
#  9   disease1                         9858 non-null   object
#  10  disease2                         9858 non-null   object
#  11  total_risk_score                 9858 non-null   int64
#  12  normalized_risk_score            9858 non-null   float64
#  13  lifestyle_risk_score             9858 non-null   int64
#  14  gender_Male                      9858 non-null   int32
#  15  region_Northwest                 9858 non-null   int32
#  16  region_Southeast                 9858 non-null   int32
#  17  region_Southwest                 9858 non-null   int32
#  18  marital_status_Unmarried         9858 non-null   int32
#  19  bmi_category_Obesity             9858 non-null   int32
#  20  bmi_category_Overweight          9858 non-null   int32
#  21  bmi_category_Underweight         9858 non-null   int32
#  22  smoking_status_Occasional        9858 non-null   int32
#  23  smoking_status_Regular           9858 non-null   int32
#  24  employment_status_Salaried       9858 non-null   int32
#  25  employment_status_Self-Employed  9858 non-null   int32
# dtypes: float64(1), int32(12), int64(8), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Feature Selection

# %%
df5 = df4.drop(['medical_history','disease1', 'disease2', 'total_risk_score','physical_activity','stress_level'], axis=1)
df5.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   56                     2             3            37               3
# 1   38                     5             2            10               2
# 2   18                     0             1             9               1
#
#    annual_premium_amount  normalized_risk_score  lifestyle_risk_score  \
# 0                  27944               0.428571                     2
# 1                  21108               0.000000                     8
# 2                   8459               0.000000                     5
#
#    gender_Male  region_Northwest  region_Southeast  region_Southwest  \
# 0            0                 0                 1                 0
# 1            0                 0                 0                 0
# 2            0                 0                 0                 1
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 0                         1                     0                        0
# 1                         0                     0                        1
# 2                         1                     0                        0
#
#    bmi_category_Underweight  smoking_status_Occasional  \
# 0                         0                          0
# 1                         0                          1
# 2                         0                          0
#
#    smoking_status_Regular  employment_status_Salaried  \
# 0                       0                           0
# 1                       0                           0
# 2                       0                           0
#
#    employment_status_Self-Employed
# 0                                1
# 1                                0
# 2                                0

# %% [markdown]
# ### Calculate VIF for Multicolinearity

# %%
df5.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_level', 'income_lakhs',
#        'insurance_plan', 'annual_premium_amount', 'normalized_risk_score',
#        'lifestyle_risk_score', 'gender_Male', 'region_Northwest',
#        'region_Southeast', 'region_Southwest', 'marital_status_Unmarried',
#        'bmi_category_Obesity', 'bmi_category_Overweight',
#        'bmi_category_Underweight', 'smoking_status_Occasional',
#        'smoking_status_Regular', 'employment_status_Salaried',
#        'employment_status_Self-Employed'],
#       dtype='object')

# %%
cm = df5.corr()

plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
X = df5.drop('annual_premium_amount', axis='columns')
y = df5['annual_premium_amount']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = ['age','number_of_dependants', 'income_level',  'income_lakhs', 'insurance_plan', 'lifestyle_risk_score']
scaler = MinMaxScaler()

X[cols_to_scale] = scaler.fit_transform(X[cols_to_scale])
X.describe()
# Out:
#                age  number_of_dependants  income_level  income_lakhs  \
# count  9858.000000           9858.000000   9858.000000   9858.000000
# mean      0.366014              0.383993      0.360756      0.219027
# std       0.258820              0.300605      0.352198      0.226801
# min       0.000000              0.000000      0.000000      0.000000
# 25%       0.111111              0.000000      0.000000      0.050505
# 50%       0.351852              0.400000      0.333333      0.151515
# 75%       0.592593              0.600000      0.666667      0.303030
# max       1.000000              1.000000      1.000000      1.000000
#
#        insurance_plan  normalized_risk_score  lifestyle_risk_score  \
# count     9858.000000            9858.000000           9858.000000
# mean         0.446135               0.326537              0.408349
# std          0.395765               0.279083              0.268302
# min          0.000000               0.000000              0.000000
# 25%          0.000000               0.000000              0.250000
# 50%          0.500000               0.428571              0.250000
# 75%          1.000000               0.428571              0.625000
# max          1.000000               1.000000              1.000000
#
#        gender_Male  region_Northwest  region_Southeast  region_Southwest  \
# count  9858.000000       9858.000000       9858.000000       9858.000000
# mean      0.401298          0.194664          0.353013          0.306452
# std       0.490186          0.395962          0.477931          0.461043
# min       0.000000          0.000000          0.000000          0.000000
# 25%       0.000000          0.000000          0.000000          0.000000
# 50%       0.000000          0.000000          0.000000          0.000000
# 75%       1.000000          0.000000          1.000000          1.000000
# max       1.000000          1.000000          1.000000          1.000000
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# count               9858.000000           9858.000000
# mean                   0.437716              0.167985
# std                    0.496131              0.373872
# min                    0.000000              0.000000
# 25%                    0.000000              0.000000
# 50%                    0.000000              0.000000
# 75%                    1.000000              0.000000
# max                    1.000000              1.000000
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# count              9858.000000               9858.000000
# mean                  0.240414                  0.141712
# std                   0.427356                  0.348773
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   1.000000                  1.000000
#
#        smoking_status_Occasional  smoking_status_Regular  \
# count                9858.000000             9858.000000
# mean                    0.150030                0.278657
# std                     0.357119                0.448361
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                1.000000
# max                     1.000000                1.000000
#
#        employment_status_Salaried  employment_status_Self-Employed
# count                 9858.000000                      9858.000000
# mean                     0.420065                         0.308176
# std                      0.493594                         0.461763
# min                      0.000000                         0.000000
# 25%                      0.000000                         0.000000
# 50%                      0.000000                         0.000000
# 75%                      1.000000                         1.000000
# max                      1.000000                         1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
#                              Column        VIF
# 0                               age   5.541063
# 1              number_of_dependants   5.320401
# 2                      income_level  12.548788
# 3                      income_lakhs  10.947288
# 4                    insurance_plan   4.147071
# 5             normalized_risk_score   3.001706
# 6              lifestyle_risk_score   3.110913
# 7                       gender_Male   1.910118
# 8                  region_Northwest   2.082989
# 9                  region_Southeast   2.952809
# 10                 region_Southwest   2.679323
# 11         marital_status_Unmarried   3.247214
# 12             bmi_category_Obesity   1.420151
# 13          bmi_category_Overweight   1.582667
# 14         bmi_category_Underweight   1.295556
# 15        smoking_status_Occasional   1.273053
# 16           smoking_status_Regular   1.704076
# 17       employment_status_Salaried   2.546359
# 18  employment_status_Self-Employed   2.401824

# %%
calculate_vif(X.drop('income_level', axis="columns"))
# Out:
#                              Column       VIF
# 0                               age  5.488217
# 1              number_of_dependants  5.306542
# 2                      income_lakhs  2.450579
# 3                    insurance_plan  3.875312
# 4             normalized_risk_score  3.001684
# 5              lifestyle_risk_score  3.110034
# 6                       gender_Male  1.901611
# 7                  region_Northwest  2.082813
# 8                  region_Southeast  2.951877
# 9                  region_Southwest  2.678296
# 10         marital_status_Unmarried  3.226402
# 11             bmi_category_Obesity  1.419612
# 12          bmi_category_Overweight  1.582523
# 13         bmi_category_Underweight  1.295283
# 14        smoking_status_Occasional  1.272269
# 15           smoking_status_Regular  1.704039
# 16       employment_status_Salaried  2.534178
# 17  employment_status_Self-Employed  2.396380

# %%
# we will drop income_lakhs due to high VIF value
X_reduced = X.drop('income_level', axis="columns")

# %% [markdown]
# ### Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.30, random_state=10)

# shape of the X_train, X_test, y_train, y_test features
print("x train: ",X_train.shape)
print("x test: ",X_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (6900, 18)
# x test:  (2958, 18)
# y train:  (6900,)
# y test:  (2958,)

# %% [markdown]
# ### Linear Regression Model

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
test_score = model_lr.score(X_test, y_test)
train_score = model_lr.score(X_train, y_train)
train_score, test_score
# Out:
# (0.9586426437876246, 0.9572516785678009)

# %%
y_pred = model_lr.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Linear Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Linear Regression ==> MSE:  3320807.9034878304 RMSE:  1822.3083996645107

# %%
X_test.shape
# Out:
# (2958, 18)

# %%
np.set_printoptions(suppress=True, precision=6)
model_lr.coef_
# Out:
# array([10675.837861,  -671.110352,  -708.275605, 13311.846824,
#         6521.438689,  4724.386632,    11.961022,    77.061876,
#           88.325309,    -9.701258,  -820.804958,  4166.09646 ,
#         2119.215673,   413.650051,  1159.508746,  3116.482686,
#           17.894652,   382.995584])

# %%
feature_importance = model_lr.coef_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Linear Regression')
plt.show()

# %% [markdown]
# ### XGBoost

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\hi\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: numpy in c:\users\hi\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\hi\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
from xgboost import XGBRegressor

model_xgb = XGBRegressor(n_estimators=20, max_depth=3)
model_xgb.fit(X_train, y_train)
model_xgb.score(X_test, y_test)
# Out:
# 0.9886000156402588

# %%
y_pred = model_xgb.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("XGBoost Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# XGBoost Regression ==> MSE:  885582.3233142267 RMSE:  941.0538365652768

# %%
model_xgb = XGBRegressor()
param_grid = {
    'n_estimators': [20, 40, 50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
}
random_search = RandomizedSearchCV(model_xgb, param_grid, n_iter=10, cv=3, scoring='r2', random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)
random_search.best_score_
# Out:
# 0.9925432205200195

# %%
random_search.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_model = random_search.best_estimator_

# %%
feature_importance = best_model.feature_importances_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in XGBoost')
plt.show()

# %% [markdown]
# ### Error Analysis

# %%
y_pred = best_model.predict(X_test)

residuals = y_pred - y_test
residuals_pct = (residuals / y_test) * 100

results_df = pd.DataFrame({
    'actual': y_test, 
    'predicted': y_pred, 
    'diff': residuals, 
    'diff_pct': residuals_pct
})
results_df.head()
# Out:
#       actual     predicted         diff  diff_pct
# 3021   13354  12226.655273 -1127.344727 -8.442000
# 6049   10701  11696.637695   995.637695  9.304156
# 6146   15146  16290.446289  1144.446289  7.556096
# 6418    8743   9265.954102   522.954102  5.981403
# 1537   27887  26731.242188 -1155.757812 -4.144432

# %%
sns.histplot(results_df['diff_pct'], kde=True)
plt.title('Distribution of Residuals')
plt.xlabel('Diff PCT')
plt.ylabel('Frequency')
plt.show()

# %%
X_test.shape
# Out:
# (2958, 18)

# %%
extreme_error_threshold = 10  # I adjust this threshold based on domain knowledge or requirements.
extreme_results_df = results_df[np.abs(results_df['diff_pct']) > extreme_error_threshold]
extreme_results_df.shape
# Out:
# (204, 4)

# %%
extreme_error_threshold = 10  # I adjust this threshold based on domain knowledge or requirements.
extreme_results_df = results_df[np.abs(results_df['diff_pct']) > extreme_error_threshold]
extreme_results_df.head()
# Out:
#       actual     predicted         diff   diff_pct
# 7800    9632   8650.812500  -981.187500 -10.186747
# 9814    6655   5948.608398  -706.391602 -10.614449
# 9970    6484   7225.738770   741.738770  11.439525
# 6882   14831  12876.333008 -1954.666992 -13.179603
# 5015    9981  11260.881836  1279.881836  12.823182

# %%
extreme_results_df.shape
# Out:
# (204, 4)

# %%
extreme_errors_pct = extreme_results_df.shape[0]*100/X_test.shape[0]
extreme_errors_pct
# Out:
# 6.896551724137931

# %% [markdown]
# ### There is about 6.9% extreme errors

# %% [markdown]
# ### Export the Model

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\hi\anaconda3\lib\site-packages (1.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from joblib import dump
import os
os.makedirs('artifacts', exist_ok=True)

dump(best_model, 'artifacts/model.joblib')

scaler_with_cols = {
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}
dump(scaler_with_cols, 'artifacts/scaler.joblib')
print('Saved artifacts/model.joblib and artifacts/scaler.joblib')
# Out:
# Saved artifacts/model.joblib and artifacts/scaler.joblib

# %%
scaler_with_cols = {
    'scaler':scaler,
    'cols_to_scale':cols_to_scale
}
scaler_with_cols
# Out:
# {'scaler': MinMaxScaler(),
#  'cols_to_scale': ['age',
#   'number_of_dependants',
#   'income_level',
#   'income_lakhs',
#   'insurance_plan',
#   'lifestyle_risk_score']}

# %%
ls artifacts
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CA94-47B2
#
#  Directory of C:\Users\Hi\Healthcare-Premium-Prediction\artifacts
#
# 07/18/2026  07:41 PM    <DIR>          .
# 07/18/2026  07:42 PM    <DIR>          ..
# 07/18/2026  07:41 PM           149,430 model.joblib
# 07/18/2026  07:41 PM             1,455 scaler.joblib
#                2 File(s)        150,885 bytes
#                2 Dir(s)  288,208,822,272 bytes free
